# %% [markdown]
# <a href="https://colab.research.google.com/github/Romeela/EDA-for-Chocolate-data/blob/main/Copy_of_EDA_case_study_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# DATASET LINK - https://www.kaggle.com/datasets/rtatman/chocolate-bar-ratings

# %% [markdown]
# **Exploratory Data Analysis with Chocolate**
#
# Analysing the dataset of Chocolate Bar Ratings to unearth key insights hidden within the data
#
#
#
#
# **Context**
#
# Chocolate is one of the most popular candies in the world. Each year, residents of the United States collectively eat more than 2.8 billions pounds. However, not all chocolate bars are created equal! This dataset contains expert ratings of over 1,700 individual chocolate bars, along with information on their regional origin, percentage of cocoa, the variety of chocolate bean used and where the beans were grown.
#
# **Rating System**
#
# 5= Elite (Transcending beyond the ordinary limits)
# 4= Premium (Superior flavor development, character and style)
# 3= Satisfactory(3.0) to praiseworthy(3.75) (well made with special qualities)
# 2= Disappointing (Passable but contains at least one significant flaw)
# 1= Unpleasant (mostly unpalatable)
#
# **Acknowledgements**
#
# The dataset used here have been acquired from Rachael Tatman's Chocolate Bar Ratings dataset on Kaggle.
# The original ratings were compiled by Brady Brelinski, Founding Member of the Manhattan Chocolate Society.

# %% [markdown]
# # **1. Load the dataset and display top 2 values**
#
# use df.columns.str.replace('\n','_') to rename columns easily

# %% [markdown]
# # **2. Remove unwanted characters in the column names and keep all the letters in lowercase**

# %% [markdown]
# # **3. Check the type of variable and also its dimensions**

# %% [markdown]
# # **4. How many rows and columns are available in the dataframe?**

# %% [markdown]
# # **5. Display the following from DataFrame**
#
# - Last 2 values
# - In between rows

# %% [markdown]
# # **6. Rename all the 9 columns with the names mentioned below**
# # *company,	bean_origin,	ref,	review_date,	cocoa_percent,	company_location,	rating,	bean_type,	broad_bean_origin*
# # **Display all the new updated column names**

# %% [markdown]
# # **7. How to get a Series from DataFrame?**

# %% [markdown]
# # **8. Slicing wrt to columns**

# %% [markdown]
# # **9. 3 Functionalities**
#
# 1. How many unique values are available in each and every column?
# 2. What are the unique values in rating?
# Ex: A.Morin, Zotter
# Ex:2.75,5.00
# 3. How many times unique values are present in Ratings column?

# %% [markdown]
# # **10. Checking for missing values and drop those rows**
# # **Search for trailing spaces in the bean_type column and replace to None**

# %% [markdown]
# # **11. Corrections of words in the column by removing punctuations.**
# *   **Convert Cocoa percent into numerical data**
# *   **Plot top 5 Bean Types**

# %% [markdown]
# # **12. Cocoa percent over the years using Groupby**

# %% [markdown]
# # **13. Seaborn Visualization: Use line Graph to display top 5 chocolate producers(countries)**

# %% [markdown]
# # **14. Consider Ratings and divide them into different categories and plot a pie chart**

# %% [markdown]
# # **15. Top Chocolate Producing Countries in the World**

# %% [markdown]
# ## **16. Plot a seaborn countplot for the count of chocolate bars versus company in ascending order**

# %% [markdown]
# # **17. Create a pivot table to show the cocoa percent and rating according to company location and review date**
# Round off the values to two decimal places

# %% [markdown]
# # **18. Plot a Matplolib or seaborn graph for showing the Average rating over the years using df.groupby**

# %% [markdown]
# # **19. Create a separate dataframe to display only the numerical columns from the dataframe**

# %%
import pandas as pd #import the pandas library
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np
df = pd.read_csv('/content/flavors_of_cacao.csv') #create the dataframe
df
# Out:
#      Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                      A. Morin                       Agua Grande  1876
# 1                      A. Morin                             Kpime  1676
# 2                      A. Morin                            Atsane  1676
# 3                      A. Morin                             Akata  1680
# 4                      A. Morin                            Quilla  1704
# ...                         ...                               ...   ...
# 1790                     Zotter                              Peru   647
# 1791                     Zotter                             Congo   749
# 1792                     Zotter                      Kerala State   749
# 1793                     Zotter                      Kerala State   781
# 1794                     Zotter                Brazil, Mitzi Blue   486
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# ...

# %% [markdown]
# # **1. Load the dataset and display top 2 values**
#
# use df.columns.str.replace('\n','_') to rename columns easily

# %%
df.head(2)
# Out:
#   Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                   A. Morin                       Agua Grande  1876
# 1                   A. Morin                             Kpime  1676
#
#    Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 0          2016            63%            France    3.75
# 1          2015            70%            France    2.75
#
#   Broad Bean\nOrigin
# 0           Sao Tome
# 1               Togo

# %% [markdown]
# # **2. Remove unwanted characters in the column names and keep all the letters in lowercase**

# %%
df.columns=df.columns.str.replace('[\n]','')
df
# Out:
# <ipython-input-3-94b3cbdee48b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns=df.columns.str.replace('[\n]','')
#      Company (Maker-if known) Specific Bean Originor Bar Name   REF  \
# 0                    A. Morin                     Agua Grande  1876
# 1                    A. Morin                           Kpime  1676
# 2                    A. Morin                          Atsane  1676
# 3                    A. Morin                           Akata  1680
# 4                    A. Morin                          Quilla  1704
# ...                       ...                             ...   ...
# 1790                   Zotter                            Peru   647
# 1791                   Zotter                           Congo   749
# 1792                   Zotter                    Kerala State   749
# 1793                   Zotter                    Kerala State   781
# ...

# %%
df['columns'] = df['columns'].str.lower()
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'columns'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # **3. Check the type of variable and also its dimensions**

# %%
df.dtypes
# Out:
# Company (Maker-if known)            object
# Specific Bean Originor Bar Name     object
# REF                                  int64
# ReviewDate                           int64
# CocoaPercent                        object
# CompanyLocation                     object
# Rating                             float64
# BeanType                            object
# Broad BeanOrigin                    object
# dtype: object

# %% [markdown]
# # **4. How many rows and columns are available in the dataframe?**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Company (Maker-if known)         1795 non-null   object
#  1   Specific Bean Originor Bar Name  1795 non-null   object
#  2   REF                              1795 non-null   int64
#  3   ReviewDate                       1795 non-null   int64
#  4   CocoaPercent                     1795 non-null   object
#  5   CompanyLocation                  1795 non-null   object
#  6   Rating                           1795 non-null   float64
#  7   BeanType                         1794 non-null   object
#  8   Broad BeanOrigin                 1794 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.3+ KB

# %% [markdown]
# # **5. Display the following from DataFrame**
#
# - Last 2 values
# - In between rows

# %%
df.tail(2)
# Out:
#      Company (Maker-if known)         bean_origin  ref  review_date  \
# 1793                   Zotter        Kerala State  781         2011
# 1794                   Zotter  Brazil, Mitzi Blue  486         2010
#
#      cocoa_percent company_location  rating bean_type broad_bean_origin
# 1793           62%          Austria    3.25                       India
# 1794           65%          Austria    3.00                      Brazil

# %%
df[350:358] #slicing the dataframe
# Out:
#     Company (Maker-if known) Specific Bean Originor Bar Name   REF  \
# 350                Caribeans                      Costa Rica   841
# 351                Caribeans                      Costa Rica   845
# 352        Carlotta Chocolat                          Arauca  1884
# 353        Carlotta Chocolat                          Tumaco  1888
# 354        Carlotta Chocolat                         Cordoba  1888
# 355        Carlotta Chocolat                           Huila  1888
# 356        Carlotta Chocolat                           Cesar  1888
# 357               Castronovo   Maya Mtn, Batch 454, Heirloom  1724
#
#      ReviewDate CocoaPercent CompanyLocation  Rating    BeanType  \
# 350        2012          72%      Costa Rica    3.00   Forastero
# 351        2012          80%      Costa Rica    2.75   Forastero
# 352        2016          65%        Colombia    3.00  Trinitario
# 353        2016          65%        Colombia    3.25  Trinitario
# ...

# %% [markdown]
# # **6. Rename all the 9 columns with the names mentioned below**
# # *company,	bean_origin,	ref,	review_date,	cocoa_percent,	company_location,	rating,	bean_type,	broad_bean_origin*
# # **Display all the new updated column names**

# %%
df.columns
# Out:
# Index(['Company (Maker-if known)', 'bean_origin', 'ref', 'review_date',
#        'cocoa_percent', 'company_location', 'rating', 'bean_type',
#        'broad_bean_origin'],
#       dtype='object')

# %%
df.columns.values[0:10] =["company","bean_origin","ref","review_date","cocoa_percent","company_location","rating","bean_type","broad_bean_origin"]
display(df)

# %%
dict = {'Company (Maker-if known)': 'company',
        'Specific Bean Originor Bar Name': 'bean_origin',
        'REF': 'ref',
        'ReviewDate': 'review_date',
        'CocoaPercent': 'cocoa_percent',
        'CompanyLocation': 'company_location',
        'Rating': 'rating',
        'BeanType': 'bean_type',
        'Broad BeanOrigin': 'broad_bean_origin'
        }
df.rename(columns=dict,
          inplace=True)
display(df)
# Out:
#      Company (Maker-if known)         bean_origin   ref  review_date  \
# 0                    A. Morin         Agua Grande  1876         2016
# 1                    A. Morin               Kpime  1676         2015
# 2                    A. Morin              Atsane  1676         2015
# 3                    A. Morin               Akata  1680         2015
# 4                    A. Morin              Quilla  1704         2015
# ...                       ...                 ...   ...          ...
# 1790                   Zotter                Peru   647         2011
# 1791                   Zotter               Congo   749         2011
# 1792                   Zotter        Kerala State   749         2011
# 1793                   Zotter        Kerala State   781         2011
# 1794                   Zotter  Brazil, Mitzi Blue   486         2010
#
#       cocoa_percent company_location  rating  bean_type broad_bean_origin
# ...

# %% [markdown]
# # **7. How to get a Series from DataFrame?**

# %%
df = pd.DataFrame(columns = ['Company (Maker-if known)', 'bean_origin', 'ref', 'review_date',
       'cocoa_percent', 'company_location', 'rating', 'bean_type',
       'broad_bean_origin'])
df
# Out:
# Empty DataFrame
# Columns: [Company (Maker-if known), bean_origin, ref, review_date, cocoa_percent, company_location, rating, bean_type, broad_bean_origin]
# Index: []

# %% [markdown]
# # **8. Slicing wrt to columns**

# %% [markdown]
# # **9. 3 Functionalities**
#
# 1. How many unique values are available in each and every column?
# 2. What are the unique values in rating?
# Ex: A.Morin, Zotter
# Ex:2.75,5.00
# 3. How many times unique values are present in Ratings column?

# %%
bean_origin = df['bean_origin']
bean_origin
# Out:
# 0              Agua Grande
# 1                    Kpime
# 2                   Atsane
# 3                    Akata
# 4                   Quilla
#                ...
# 1790                  Peru
# 1791                 Congo
# 1792          Kerala State
# 1793          Kerala State
# 1794    Brazil, Mitzi Blue
# Name: bean_origin, Length: 1795, dtype: object

# %%
bean_origin = df.bean_origin.unique()
bean_origin
# Out:
# array(['Agua Grande', 'Kpime', 'Atsane', ..., 'Indianer, Raw',
#        'Kerala State', 'Brazil, Mitzi Blue'], dtype=object)

# %%
df.bean_origin.nunique()
# Out:
# 1039

# %%
company_location = df['company_location']
company_location
# Out:
# 0        France
# 1        France
# 2        France
# 3        France
# 4        France
#          ...
# 1790    Austria
# 1791    Austria
# 1792    Austria
# 1793    Austria
# 1794    Austria
# Name: company_location, Length: 1795, dtype: object

# %%
Company (Maker-if known) = df['Company (Maker-if known)']
Company (Maker-if known)
# Out:
#   File "<ipython-input-38-53b8e5ff47ff>", line 1
#     Company (Maker-if known) = df['Company (Maker-if known)']
#                    ^
# SyntaxError: invalid syntax

# %%
df.company_location.nunique()
# Out:
# 60

# %%
rating = df['rating']
rating
# Out:
# 0       3.75
# 1       2.75
# 2       3.00
# 3       3.50
# 4       3.50
#         ...
# 1790    3.75
# 1791    3.00
# 1792    3.50
# 1793    3.25
# 1794    3.00
# Name: rating, Length: 1795, dtype: float64

# %%
df.rating.nunique()
# Out:
# 13

# %%
df['rating'].value_counts()
# Out:
# 3.50    392
# 3.00    341
# 3.25    303
# 2.75    259
# 3.75    210
# 2.50    127
# 4.00     98
# 2.00     32
# 2.25     14
# 1.50     10
# 1.00      4
# 1.75      3
# 5.00      2
# Name: rating, dtype: int64

# %% [markdown]
# # **10. Checking for missing values and drop those rows**
# # **Search for trailing spaces in the bean_type column and replace to None**

# %%
df.isnull().sum()
# Out:
# Company (Maker-if known)    0
# bean_origin                 0
# ref                         0
# review_date                 0
# cocoa_percent               0
# company_location            0
# rating                      0
# bean_type                   0
# broad_bean_origin           1
# dtype: int64

# %%
df.fillna(0)
# Out:
#      Company (Maker-if known)         bean_origin   ref  review_date  \
# 0                    A. Morin         Agua Grande  1876         2016
# 1                    A. Morin               Kpime  1676         2015
# 2                    A. Morin              Atsane  1676         2015
# 3                    A. Morin               Akata  1680         2015
# 4                    A. Morin              Quilla  1704         2015
# ...                       ...                 ...   ...          ...
# 1790                   Zotter                Peru   647         2011
# 1791                   Zotter               Congo   749         2011
# 1792                   Zotter        Kerala State   749         2011
# 1793                   Zotter        Kerala State   781         2011
# 1794                   Zotter  Brazil, Mitzi Blue   486         2010
#
#      cocoa_percent company_location  rating  bean_type broad_bean_origin
# ...

# %%
df.dropna()
# Out:
#      Company (Maker-if known)         bean_origin   ref  review_date  \
# 0                    A. Morin         Agua Grande  1876         2016
# 1                    A. Morin               Kpime  1676         2015
# 2                    A. Morin              Atsane  1676         2015
# 3                    A. Morin               Akata  1680         2015
# 4                    A. Morin              Quilla  1704         2015
# ...                       ...                 ...   ...          ...
# 1790                   Zotter                Peru   647         2011
# 1791                   Zotter               Congo   749         2011
# 1792                   Zotter        Kerala State   749         2011
# 1793                   Zotter        Kerala State   781         2011
# 1794                   Zotter  Brazil, Mitzi Blue   486         2010
#
#      cocoa_percent company_location  rating  bean_type broad_bean_origin
# ...

# %%
df['bean_type'] = df['bean_type'].fillna('none')
df['bean_type']
# Out:
# 0
# 1
# 2
# 3
# 4
#           ...
# 1790
# 1791    Forastero
# 1792    Forastero
# 1793
# 1794
# Name: bean_type, Length: 1795, dtype: object

# %%
df.dropna()
df
# Out:
#      Company (Maker-if known)         bean_origin   ref  review_date  \
# 0                    A. Morin         Agua Grande  1876         2016
# 1                    A. Morin               Kpime  1676         2015
# 2                    A. Morin              Atsane  1676         2015
# 3                    A. Morin               Akata  1680         2015
# 4                    A. Morin              Quilla  1704         2015
# ...                       ...                 ...   ...          ...
# 1790                   Zotter                Peru   647         2011
# 1791                   Zotter               Congo   749         2011
# 1792                   Zotter        Kerala State   749         2011
# 1793                   Zotter        Kerala State   781         2011
# 1794                   Zotter  Brazil, Mitzi Blue   486         2010
#
#      cocoa_percent company_location  rating  bean_type broad_bean_origin
# ...

# %% [markdown]
# # **11. Corrections of words in the column by removing punctuations.**
# *   **Convert Cocoa percent into numerical data**
# *   **Plot top 5 Bean Types**

# %%
df["cocoa_percent"] = df["cocoa_percent"].str.rstrip("%").astype("float") / 100
df
# Out:
#      Company (Maker-if known)         bean_origin   ref  review_date  \
# 0                    A. Morin         Agua Grande  1876         2016
# 1                    A. Morin               Kpime  1676         2015
# 2                    A. Morin              Atsane  1676         2015
# 3                    A. Morin               Akata  1680         2015
# 4                    A. Morin              Quilla  1704         2015
# ...                       ...                 ...   ...          ...
# 1790                   Zotter                Peru   647         2011
# 1791                   Zotter               Congo   749         2011
# 1792                   Zotter        Kerala State   749         2011
# 1793                   Zotter        Kerala State   781         2011
# 1794                   Zotter  Brazil, Mitzi Blue   486         2010
#
#       cocoa_percent company_location  rating  bean_type broad_bean_origin
# ...

# %%
df.sort_values("bean_type", ascending=False).groupby("cocoa_percent")

# %%
df.sort_values("bean_type", ascending=False)
# Out:
#                     Company (Maker-if known)  \
# 0                                   A. Morin
# 999                                    Madre
# 997                                    Madre
# 996                                    Madre
# 995                                    Madre
# ..                                       ...
# 798     Heirloom Cacao Preservation (Zokoko)
# 791   Heirloom Cacao Preservation (Guittard)
# 790   Heirloom Cacao Preservation (Fruition)
# 719                                 Fruition
# 789  Heirloom Cacao Preservation (Brasstown)
#
#                             bean_origin   ref  review_date  cocoa_percent  \
# 0                           Agua Grande  1876         2016           0.63
# 999             Hamakua Coast, Kokoleka   991         2012           0.70
# 997                       Choobua, Kona  1089         2013           0.70
# 996                              Brazil  1085         2013           0.70
# ...

# %% [markdown]
# # **12. Cocoa percent over the years using Groupby**

# %%
df.sort_values("cocoa_percent", ascending=False).groupby("review_date").head(2)
# Out:
#             Company (Maker-if known)                           bean_origin  \
# 557                           Domori                    IL100, H. San Jose
# 330                          C-Amaro                               Ecuador
# 125              Artisan du Chocolat                             Venezuela
# 1467                          Sirene  Camino Verde P., Balao, Guayas, 2012
# 1466                          Sirene                Somia Plantation, 2012
# 437                  Claudio Corallo                              Principe
# 1204                            Ocho                         Sang Yum Coop
# 1251                          Pacari                                   Raw
# 1411                        S.A.I.D.                           100 percent
# 249           Bouga Cacao (Tulicorp)               El Oro, Hacienda de Oro
# 245                           Bonnat                           One Hundred
# ...

# %%
df.sort_values("cocoa_percent", ascending=False)
# Out:
#            Company (Maker-if known)                           bean_origin  \
# 557                          Domori                    IL100, H. San Jose
# 330                         C-Amaro                               Ecuador
# 125             Artisan du Chocolat                             Venezuela
# 1467                         Sirene  Camino Verde P., Balao, Guayas, 2012
# 1466                         Sirene                Somia Plantation, 2012
# ...                             ...                                   ...
# 343                Caoni (Tulicorp)                              Los Rios
# 1423  Santander (Compania Nacional)                   Colombian Semi Dark
# 90                             AMMA     Monte Alegre, 3 diff. plantations
# 984                           Luker                                 Selva
# 429          Chokolat Elot (Girard)                            Guadeloupe
#
#        ref  review_date  cocoa_percent company_location  rating  \
# ...

# %% [markdown]
# # **13. Seaborn Visualization: Use line Graph to display top 5 chocolate producers(countries)**

# %%
df.corr()
# Out:
#                     ref  review_date  cocoa_percent    rating
# ref            1.000000     0.985076       0.037791  0.101030
# review_date    0.985076     1.000000       0.038177  0.099846
# cocoa_percent  0.037791     0.038177       1.000000 -0.164820
# rating         0.101030     0.099846      -0.164820  1.000000

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
maxValueIndex = df.max(axis=1)
# Out:
# <ipython-input-25-b6ff078eb4f4>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   maxValueIndex = df.max(axis=1)

# %%
#df.sort_values("Company(Maker-if known)", ascending=False).groupby("review_date").head(2)
df.sort_values("company(Maker-if known)", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-22aeb5e45a27> in <module>
#       1 #df.sort_values("Company(Maker-if known)", ascending=False).groupby("review_date").head(2)
# ----> 2 df.sort_values("company(Maker-if known)", ascending=False)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# -> 6259             k = self._get_label_or_level_values(by, axis=axis)
#    6260
# ...

# %%
plt.bar(cocoa_percent,review_date)
sns.barplot(cocoa_percent,review_date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-a86f6846fc09> in <module>
# ----> 1 plt.bar(cocoa_percent,review_date)
#       2 sns.barplot(cocoa_percent,review_date)
#
# NameError: name 'cocoa_percent' is not defined
